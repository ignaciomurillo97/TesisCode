# %%
# %pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (1.2.10)
# Requirement already satisfied: Pillow in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (9.4.0)
# Requirement already satisfied: affine in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (2.3.0)
# Requirement already satisfied: attrs in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (22.1.0)
# Requirement already satisfied: certifi in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (2023.7.22)
# Requirement already satisfied: click>=4.0 in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (1.24.3)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: click-plugins in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from rasterio) (68.0.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /Users/nacho/anaconda3/envs/EarthEngine/lib/python3.11/site-packages (from snuggs>=1.4.1->rasterio) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def plot_surface_from_array(Z, cmap='gray'):
    """
    Plots a 2D numpy array as a surface plot.
    
    Parameters:
    - Z: 2D numpy array containing the Z values.
    - cmap: Colormap to use for the surface.
    - title: Title for the plot.
    """
    
    # Create a meshgrid for X and Y based on the shape of Z
    x = np.linspace(0, Z.shape[1]-1, Z.shape[1])
    y = np.linspace(0, Z.shape[0]-1, Z.shape[0])
    X, Y = np.meshgrid(x, y)
    
    # Create a figure and a 3D axis
    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(111, projection='3d')
    
    # Hide axes ticks
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])
    
    # Plot the surface
    ax.plot_surface(X, Y, Z, cmap=cmap)
    
    plt.show()

# %%
plot_surface_from_array(a.next())
