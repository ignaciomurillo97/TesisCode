# %%
import rasterio as rs
import numpy as np
from matplotlib import pyplot as plt

geotiff_dir = "./download2/"
geotiff_file = "elev_0_-22.269158650668658_145.64846199698434_20230813_134144.tif"
png_output_dir = "./png_output/"
png_output = "test.png"

dataset = rs.open(geotiff_dir + geotiff_file)
data = dataset.read()

print(dataset.profile)
# No. of bands
print (dataset.count)
# Image resolution
print (dataset.height, dataset.width)
# CRS
print (dataset.crs)
print(data.shape)
print(data.dtype)

crs = dataset.crs
transform = dataset.transform

plt.imshow(data[0], interpolation='nearest')
plt.show()


# with rs.open(png_output_dir + png_output, 'w', driver='PNG',
#                width=data.shape[1], height=data.shape[2],
#                count=1, dtype=data.dtype, nodata=None,
#                transform=transform, crs=crs, format='PNG') as dst:
#     dst.write(data, indexes=None)
# Out:
# {'driver': 'GTiff', 'dtype': 'int16', 'nodata': None, 'width': 150, 'height': 149, 'count': 1, 'crs': CRS.from_epsg(4326), 'transform': Affine(0.0002694945852358564, 0.0, 145.62828198949978,
#        0.0, -0.0002694945852358564, -22.249069535924015), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'lzw', 'interleave': 'band'}
# 1
# 149 150
# EPSG:4326
# (1, 149, 150)
# int16

# %%
import rasterio as rs
from os import listdir
from os.path import isfile, join
output_format = 'GIF'

geotiff_dir = "./download2/"
png_output_dir = "./png_output2/"
contents = listdir(geotiff_dir)

crs = dataset.crs
transform = dataset.transform

print("dirs:", contents)

for file in contents:
    filepath = join(geotiff_dir, file)
    print("filepath: ", filepath)
    if isfile(filepath):
        print("it's a file!")

        dataset = rs.open(filepath)
        data = dataset.read()
        png_filename = file.replace(".tif", ".gif")
        png_filepath = join(png_output_dir, png_filename)

        print("dataset read")

        with rs.open(png_filepath, 'w', driver=output_format,
                    width=data.shape[1], height=data.shape[2],
                    count=1, dtype=data.dtype, nodata=None,
                    transform=transform, crs=crs, format=output_format) as dst:
            dst.write(data, indexes=None)

        print("written: ", png_filename)
# Out:
# dirs: ['elev_358_-26.813836902552584_137.32474882581084_20230813_134144.tif', 'elev_211_-29.64940110861792_137.6070663523978_20230813_134144.tif', 'elev_36_-22.852141722257954_137.94707126668223_20230813_134144.tif', 'elev_346_-24.992893294751582_141.00030755394968_20230813_134144.tif', 'elev_151_-18.0883524200729_131.73114397660942_20230813_134144.tif', 'elev_360_-20.633492918288628_141.43836716216995_20230813_134144.tif', 'elev_437_-22.5568980498662_142.7587537537833_20230813_134144.tif', 'elev_102_-27.5784267369456_140.04168419451085_20230813_134144.tif', 'elev_493_-29.281956628368796_143.74285295411283_20230813_134144.tif', 'elev_45_-19.701348992870575_140.56307608044548_20230813_134144.tif', 'elev_288_-21.00685732266897_130.27521970464576_20230813_134144.tif', 'elev_155_-27.994155491880395_141.9312576886894_20230813_134144.tif', 'elev_260_-18.82803353897953_143.42987792361123_20230813_134144.tif', 'elev_270_-21.605749774579273_125.89688635804204_20230813_134144.tif', 'elev_482_-20.92219053345812_132.29971111576333_20230813_134144.tif', 'elev_376_-23.584942117444886_123.33462416715933_20230813_134144.tif', 'elev_440_-18.610497470868445_135.06501065023335_20230813_134144.tif', 'elev_182_-19.82754347643745_136.38123335596813_20230813_134144.tif', 'elev_119_-20.7543757282627_133.89853147738836_20230813_134144.tif', 'elev_264_-23.197765825185595_143.10069029572634_20230813_134144.tif', 'elev_183_-27.53314280313696_137.57571997355012_20230813_134144.tif', 'elev_419_-17.543183880828174_132.79750517423054_20230813_134144.tif', 'elev_354_-22.062096251541217_135.03766921363047_20230813_134144.tif', 'elev_26_-20.685424682315524_128.86530204868453_20230813_134144.tif', 'elev_257_-22.5277646939978_132.96616478799587_20230813_134144.tif', 'elev_361_-17.223423772498112_137.95470338882726_20230813_134144.tif', 'elev_337_-21.268311851496115_143.5396703749913_20230813_134144.tif', 'elev_375_-22.547032934380123_144.30860565194797_20230813_134144.tif', 'elev_485_-30.34380664709525_131.56398372884937_20230813_134144.tif', 'elev_202_-18.885501160044193_133.98642009510635_20230813_134144.tif', 'elev_181_-26.121496683867747_140.38915453345294_20230813_134144.tif', 'elev_159_-27.71274661376968_142.71293264508972_20230813_134144.tif', 'elev_274_-30.01928582468176_131.23046989803512_20230813_134144.tif', 'elev_277_-18.453122749307017_135.79433618815176_20230813_134144.tif', 'elev_50_-23.95024303441722_125.15630407733967_20230813_134144.tif', 'elev_295_-24.1883186995522_132.94250638282088_20230813_134144.tif', 'elev_280_-22.755592373125086_127.90378423463409_20230813_134144.tif', 'elev_472_-23.549019465538287_136.61807243460458_20230813_134144.tif', 'elev_210_-23.01857195638979_141.27278163041126_20230813_134144.tif', 'elev_303_-19.59977217339253_132.8696894861643_20230813_134144.tif', 'elev_57_-27.329424716790683_132.67363037684166_20230813_134144.tif', 'elev_438_-22.039630970043632_127.06121886121633_20230813_134144.tif', 'elev_366_-26.12562123264726_139.37343140574507_20230813_134144.tif', 'elev_139_-26.37552970977047_123.96760525438998_20230813_134144.tif', 'elev_71_-26.91922820079264_141.11163397822472_20230813_134144.tif', 'elev_227_-18.616189828133333_131.576744151667_20230813_134144.tif', 'elev_311_-20.73871034866827_123.72041194533064_20230813_134144.tif', 'elev_404_-28.910390531288453_142.2613115185025_20230813_134144.tif', 'elev_302_-19.719279495982192_142.04745682111485_20230813_134144.tif', 'elev_185_-24.556386805637807_131.16839646484635_20230813_134144.tif', 'elev_22_-28.337298994721763_130.08169186326967_20230813_134144.tif', 'elev_55_-20.926146429552496_133.1780824627598_20230813_134144.tif', 'elev_252_-20.91406292893485_143.9467912710559_20230813_134144.tif', 'elev_368_-23.47121850489065_143.60128485003796_20230813_134144.tif', 'elev_88_-29.886192412682995_131.1598197084869_20230813_134144.tif', 'elev_78_-25.05383309466233_126.16726825503684_20230813_134144.tif', 'elev_8_-21.412868926806976_127.97183657665059_20230813_134144.tif',  ...
# filepath:  ./download2/elev_358_-26.813836902552584_137.32474882581084_20230813_134144.tif
# it's a file!
# dataset read
# ---------------------------------------------------------------------------
# CPLE_NotSupportedError                    Traceback (most recent call last)
# Cell In[5], line 28
#      24 png_filepath = join(png_output_dir, png_filename)
#      26 print("dataset read")
# ---> 28 with rs.open(png_filepath, 'w', driver=output_format,
#      29             width=data.shape[1], height=data.shape[2],
#      30             count=1, dtype=data.dtype, nodata=None,
#      31             transform=transform, crs=crs, format=output_format) as dst:
#      32     dst.write(data, indexes=None)
#      34 print("written: ", png_filename)
#
# File rasterio/_base.pyx:395, in rasterio._base.DatasetBase.__exit__()
#
# File rasterio/_base.pyx:386, in rasterio._base.DatasetBase.close()
#
# File rasterio/_io.pyx:2125, in rasterio._io.BufferedDatasetWriterBase.stop()
#
# File rasterio/_err.pyx:216, in rasterio._err.exc_wrap_pointer()
#
# CPLE_NotSupportedError: PNG driver doesn't support data type Int16. Only eight bit (Byte) and sixteen bit (UInt16) bands supported.

# %%
data[0,0,0]
# Out:
# 857
