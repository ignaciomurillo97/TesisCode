# %%
import ee
# ee.Authenticate()
service_account = 'ignaciomurillo97@round-gasket-183822.iam.gserviceaccount.com'
credentials = ee.ServiceAccountCredentials(service_account, './round-gasket-183822-5ee7a3855b33.json')
ee.Initialize()

# %%
import requests
from PIL import Image
from io import BytesIO
from IPython.display import Image as IPyImage

apiKey = '46b34ce194a04492b68926a28c2a629f'
# Get static map from Geoapify
def get_static_map(lat, lon, zoom, width=500, height=500, scale=1, format='jpeg', api_key=apiKey):
    url = "https://api.geoapify.com/v1/staticmap"
    params = {
        "style": "osm-carto",
        "width": width,
        "height": height,
        "zoom": zoom,
        "center": f"lonlat:{lon},{lat}",
        "scale": scale,
        "format": format,
        "apiKey": api_key
    }
    response = requests.get(url, params=params)
    return response.content

# %% [markdown]
# # Generate Dataset

# %%
import random

def random_point_in_bounding_box(latlon1, latlon2):
    lat1, lon1 = latlon1
    lat2, lon2 = latlon2
    lat = random.uniform(lat1, lat2)
    lon = random.uniform(lon1, lon2)
    return (lat, lon)

# %%
from datetime import datetime

# coordinates = [(40.7128, -74.0060), (51.5074, -0.1278), (-33.8651, 151.2094)]
SAMPLES = 2000 
latlon1 = (-17.0357, 122.9197)
latlon2 = (-30.3538, 145.7713)
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
drive_folder = f'GoogleEarthEngineExport'

coordinates = []
while len(coordinates) < SAMPLES:
  point = random_point_in_bounding_box(latlon1, latlon2)
  coordinates.append(point)

f"dirname: {drive_folder}, bounding box {latlon1, latlon2} ,coordinates: {coordinates}"
# Out:
# 'dirname: GoogleEarthEngineExport, bounding box ((-17.0357, 122.9197), (-30.3538, 145.7713)) ,coordinates: [(-17.62823590669136, 144.77128148425535), (-25.923096602116615, 135.16819998473778), (-20.776374464796895, 127.5824381926835), (-23.8055166389971, 141.23926075410742), (-19.31611461100816, 139.4983136811962), (-17.715784110036868, 139.6436707910275), (-18.903365507482313, 142.81359679886873), (-20.84652641384368, 124.91568983117358), (-28.88246374782503, 137.85883854101147), (-27.428802408719086, 134.98063017222086), (-22.405889238689372, 134.12755966594673), (-28.427708002994443, 137.5579074616342), (-25.774633348920297, 127.59086845608945), (-19.498285106398953, 142.12790550198005), (-28.74060276323362, 143.0730994341446), (-21.659862104847825, 142.93129427199366), (-22.267882460829778, 131.54792833203456), (-28.370432088297598, 133.1042990441868), (-23.072703642600032, 133.9202440371022), (-25.82391522385374, 130.62348383588238), (-28.858307719072744, 131.28983327871754), (-28.21828959839964, 127.816453997496), (-24.42876212240661, 136.26068171897552), (-26.263245314225998, 132.2340022232355), (-21.71873764394031, 143.58444730188265), (-19.913082047554234, 122.96620151588493), (-23.330831974786605, 133.243633872263), (-18.17537719655718, 135.99725415472412), (-24.929444976367616, 129.86264653405988), (-19.02185712928552, 124.35234382649743), (-20.351712837357848, 123.1822533604709), (-26.276981213474073, 125.74508609262848), (-24.272642476406922, 134.87440125277908), (-18.15497403461311, 142.61516760854454), (-20.281643458188256, 124.93777623982365), (-25.910217091336648, 123.67909321255517), (-29.92047006539714, 128.77205392073705), (-20.34007799135613, 140.63929799481363), (-30.021196334454167, 141.69062642594423), (-17.09545589277172, 136.56584091626942), (-27.549396853379022, 144.67700532662678), (-30.159602097858446, 131.58285653823575), (-24.22169984528447, 129.14733331715408), (-20.11293746401726, 142.76257412857356), (-24.066613557882473, 134.794303474614), (-24.86704278979434, 143.7599793346558), (-21.274049785882255, 144.23503435709446), (-19.211892864814345, 128.314305309094), (-25.51531738810094, 142.29446455729993), (-25.580173487310645, 137.79961759908815), (-22.911492796256944, 127.1686463698059), (-18.86770892314109, 133.83592099560892), (-18.810622063804207, 123.39000815392835), (-23.13483588456328, 127.25484823338381), (-20.226288451835288, 140.59574157781174), (-24.920605704143696, 131.81847612378746), (-24.406129190436808, 135.14805173779635), (-21.721860858836525, 131.82313039342907), (-27.356781197894996, 144.97524223293883), (-20.727382707456318, 140.38147945692145), (-22.21015987984439, 134.79564585111373), (-18.645080493622267, 137.6793805755783), (-23.1774342651802, 133.8691813687759), (-29.840930699254116, 144.85591251564892), (-23.281446659022926, 142.5293208998996), (-20.011542341127033, 140.37257167794567), (-27.40424148926453, 125.04180805093596), (-22.92747264741135, 123.50318667717342), (-24.133467252108687, 143.81680564689643), (-21.293551165576808, 138.38323931836874), (-29.438045448099928, 133.6171100896824), (-25.474532339947892, 140.3987644757951), (-20.715350131143836, 125.5989774558893), (-22.202126469736687, 144.4960306789264), (-22.547190750807, 137.72553534579464), (-27.40182163086857, 140.3502170246209), (-29.516593832893903, 130.1601250195817), (-25.340201277852486, 141.05634185118944), (-21.260657075340507, 142.7165285517257), (-26.594420454979627, 125.27338871552904), (-18.132174263299277, 143.25530682344439), (-29.755721339056173, 127.07957592876852), (-18.883800654505034, 126.58280618680963), (-24.06447469717644, 145.65006267290454), (-25.859674694271504, 139.95584052154763), (-23.251605199997364, 126.64983852111645), (-27.32417490852572, 129.2156721755076), (-20.664761946978174, 135.18297407011124), (-18.47724124172701, 131.12731515994085), (-24.562137889823354, 126.0622761617886), (-23.16561549342821, 137.3423658966912), (-20.794116633370166, 140.29745497544226), (-26 ...

# %%
import time
# display static map of coordinates
for coordinate in coordinates:
  lat, lon = coordinate
  img = get_static_map(lat, lon, 5)
  img = Image.open(BytesIO(img))
  display(img)
  time.sleep(0.5)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %%
def fetch_elevation(coordinates, folder, buffer):
    tasks = []
    
    # Loop over the list of coordinates
    for i, coord in enumerate(coordinates):
        # Extract the latitude and longitude from the coordinate tuple
        lat, lon = coord
        
        # Fetch the elevation data for the current coordinate
        region = ee.Geometry.BBox(lon - buffer, lat - buffer, lon + buffer, lat + buffer)
        elv_image = ee.Image('USGS/SRTMGL1_003').clip(region)
        
        # filename including coordinates
        # filename = f'projects/elevation/{i}/{lat:.4f}_{lon:.4f}_{ct.strftime("%Y%m%d_%H%M%S")}'.replace(".", "-")
        filename = f'elev_{i}_{lat}_{lon}_{ct.strftime("%Y%m%d_%H%M%S")}'
        # Create a task to export the image to Google Drive
        task = ee.batch.Export.image.toDrive(image=elv_image,
                                              description=f'elevation_{i}',
                                              folder=folder,
                                              fileNamePrefix=filename,
                                              region=elv_image.geometry().bounds().getInfo()['coordinates'],
                                              scale=10)

        # # task = ee.batch.Export.image.toAsset(
        # #                                       image=elv_image,
        # #                                       description=f'elevation_{i}',
        # #                                       assetId=filename,
        # #                                       region=elv_image.geometry().bounds().getInfo()['coordinates'],
        # #                                       scale=30)
        
        # Start the export task
        task.start()
        
        # Add the task to the list of tasks
        tasks.append(task)
    
    # Return the list of export tasks
    return tasks

# %%
import datetime
ct = datetime.datetime.now()

def export_region_around_coordinate(coordinates, folder, buffer):
    tasks = []
    
    # Loop over the list of coordinates
    for i, coord in enumerate(coordinates):
        latitude, longitude = coord
        # Define a point for the given coordinate
        point = ee.Geometry.Point([longitude, latitude])

        # Load the Sentinel-2 surface reflectance image collection for the date range of interest
        collection = ee.ImageCollection('COPERNICUS/S2_SR') \
            .filterBounds(point) \
            .filterDate('2020-01-01', '2020-12-31')

        # Filter out cloudy pixels
        # filteredCollection = collection \
        #     .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10))

        # Select the first image in the filtered collection
        # image = filteredCollection.first()
        image = collection.first().select('B2')

        # Define the image export parameters
        filename = f'color_{i}_{latitude}_{longitude}_{ct.strftime("%Y%m%d_%H%M%S")}'
        export_params = {
            'image': image,
            'description':f'elevation_{i}',
            'AssetId':filename,
            'scale': 10,
            'region': point.buffer(buffer).bounds().getInfo()['coordinates'],
            'fileFormat': 'GeoTIFF',
            'folder': drive_folder,
            'skipEmptyTiles': True,
            'formatOptions': {
                'cloudOptimized': True
            }
        }

        # Export the image
        task = ee.batch.Export.image.toDrive(**export_params)
        task.start()
        tasks.append(task)
    return tasks

# %%
import time

# Fetch the elevation data for the coordinates and save them to Google Drive
print("creating fetch tests")
tasks = fetch_elevation(coordinates, drive_folder, 0.02)
print("fetch tasks created successfully")
# tasks.append(export_region_around_coordinate(coordinates, drive_folder, 10000))
# tasks = export_region_around_coordinate(coordinates, drive_folder, 10000)

# Wait for all the export tasks to complete
for task in tasks:
    print(f'Waiting for task {task.id} to complete...')
    while task.active():
        time.sleep(5)
    print(f'Task {task.id} completed with status {task.status()}')

print(f'all tasks completed!')
# Out:
# creating fetch tests
# fetch tasks created successfully
# Waiting for task ISW375PPOAM4YVKPBNKB4CGG to complete...
# Task ISW375PPOAM4YVKPBNKB4CGG completed with status {'state': 'COMPLETED', 'description': 'elevation_0', 'creation_timestamp_ms': 1692070774972, 'update_timestamp_ms': 1692070788987, 'start_timestamp_ms': 1692070781652, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1454487293958664, 'id': 'ISW375PPOAM4YVKPBNKB4CGG', 'name': 'projects/earthengine-legacy/operations/ISW375PPOAM4YVKPBNKB4CGG'}
# Waiting for task 4SF3E7O4BZMBJ7CABNDJPYDR to complete...
# Task 4SF3E7O4BZMBJ7CABNDJPYDR completed with status {'state': 'COMPLETED', 'description': 'elevation_1', 'creation_timestamp_ms': 1692070776336, 'update_timestamp_ms': 1692070791628, 'start_timestamp_ms': 1692070781686, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.15281786024570465, 'id': '4SF3E7O4BZMBJ7CABNDJPYDR', 'name': 'projects/earthengine-legacy/operations/4SF3E7O4BZMBJ7CABNDJPYDR'}
# Waiting for task CTZFUTKPQNUFQEJEJL652HKP to complete...
# Task CTZFUTKPQNUFQEJEJL652HKP completed with status {'state': 'COMPLETED', 'description': 'elevation_2', 'creation_timestamp_ms': 1692070778403, 'update_timestamp_ms': 1692070789600, 'start_timestamp_ms': 1692070781686, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.13852107524871826, 'id': 'CTZFUTKPQNUFQEJEJL652HKP', 'name': 'projects/earthengine-legacy/operations/CTZFUTKPQNUFQEJEJL652HKP'}
# Waiting for task KUUYJ7WL4X6UMYQH55EJPKM4 to complete...
# Task KUUYJ7WL4X6UMYQH55EJPKM4 completed with status {'state': 'COMPLETED', 'description': 'elevation_3', 'creation_timestamp_ms': 1692070779641, 'update_timestamp_ms': 1692070823604, 'start_timestamp_ms': 1692070792193, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.8466622829437256, 'id': 'KUUYJ7WL4X6UMYQH55EJPKM4', 'name': 'projects/earthengine-legacy/operations/KUUYJ7WL4X6UMYQH55EJPKM4'}
# Waiting for task 44X2LIKRXAXL3S64QJLI7KKX to complete...
# Task 44X2LIKRXAXL3S64QJLI7KKX completed with status {'state': 'COMPLETED', 'description': 'elevation_4', 'creation_timestamp_ms': 1692070780941, 'update_timestamp_ms': 1692070810304, 'start_timestamp_ms': 1692070802022, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.22282032668590546, 'id': '44X2LIKRXAXL3S64QJLI7KKX', 'name': 'projects/earthengine-legacy/operations/44X2LIKRXAXL3S64QJLI7KKX'}
# Waiting for task AFG34TA3LHG4ROSE5XRUTAEU to complete...
# Task AFG34TA3LHG4ROSE5XRUTAEU completed with status {'state': 'COMPLETED', 'description': 'elevation_5', 'creation_timestamp_ms': 1692070782145, 'update_timestamp_ms': 1692070809007, 'start_timestamp_ms': 1692070802019, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1745709329843521, 'id': 'AFG34TA3LHG4ROSE5XRUTAEU', 'name': 'projects/earthengine-legacy/operations/AFG34TA3LHG4ROSE5XRUTAEU'}
# Waiting for task ADSUJYSKFJWGPBGQOGFFDMYH to complete...
# Task ADSUJYSKFJWGPBGQOGFFDMYH completed with status {'state': 'COMPLETED', 'description': 'elevation_6', 'creation_timestamp_ms': 1692070783337, 'update_timestamp_ms': 1692070812368, 'start_timestamp_ms': 1692070802016, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.11971130222082138, 'id': 'ADSUJYSKFJWGPBGQOGFFDMYH', 'name': 'projects/earthengine-legacy/operations/ADSUJYSKFJWGPBGQOGFFDMYH'}
# Waiting for task VAELUE4HAAJKGMRYCLG2YCVD to complete...
# Task VAELUE4HAAJKGMRYCLG2YCVD completed with status {'state': 'COMPLETED', 'description': 'elevation_7', 'creation_timestamp_ms': 1692070784733, 'update_timestamp_ms': 1692070828637, 'start_timestamp_ms': 1692070821366, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.15492092072963715, 'id': 'VAELUE4HAAJKGMRYCLG2YCVD', 'name': 'projects/earthengine-legacy/operations/VAELUE4HAAJKGMRYCLG2YCVD'}
# Waiting for task PXDEWHPI3RXRHNZBYYAHJFNF to complete...
# Task PXDEWHPI3RXRHNZBYYAHJFNF completed with status {'state': 'COMPLETED', 'description': 'elevation_8', 'creation_timestamp_ms': 1692070785951, 'update_timestamp_ms': 1692070828251, 'start_timestamp_ms': 1692070821359, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.13689813017845154, 'id': 'PXDEWHPI3RXRHNZBYYAHJFNF', 'name': 'projects/earthengine-legacy/operations/PXDEWHPI3RXRHNZBYYAHJFNF'}
# Waiting for task SN24W633Y4KSHJZFSCP7ZDZV to complete...
# Task SN24W633Y4KSHJZFSCP7ZDZV completed with status {'state': 'COMPLETED', 'description': 'elevation_9', 'creation_timestamp_ms': 1692070787372, 'update_timestamp_ms': 1692070838234, 'start_timestamp_ms': 1692070831368, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.13835279643535614, 'id': 'SN24W633Y4KSHJZFSCP7ZDZV', 'name': 'projects/earthengine-legacy/operations/SN24W633Y4KSHJZFSCP7ZDZV'}
# Waiting for task 7UJBXWHMGSLQW2WGV7WRDFXN to complete...
# Task 7UJBXWHMGSLQW2WGV7WRDFXN completed with status {'state': 'COMPLETED', 'description': 'elevation_10', 'creation_timestamp_ms': 1692070788537, 'update_timestamp_ms': 1692070839321, 'start_timestamp_ms': 1692070831408, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.20050109922885895, 'id': '7UJBXWHMGSLQW2WGV7WRDFXN', 'name': 'projects/earthengine-legacy/operations/7UJBXWHMGSLQW2WGV7WRDFXN'}
# Waiting for task KYDOMEEMJZQUFFMUHQPESSRY to complete...
# Task KYDOMEEMJZQUFFMUHQPESSRY completed with status {'state': 'COMPLETED', 'description': 'elevation_11', 'creation_timestamp_ms': 1692070789989, 'update_timestamp_ms': 1692070840765, 'start_timestamp_ms': 1692070831405, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.13418658077716827, 'id': 'KYDOMEEMJZQUFFMUHQPESSRY', 'name': 'projects/earthengine-legacy/operations/KYDOMEEMJZQUFFMUHQPESSRY'}
# Waiting for task BEXRZKWY2OHOKLWZHDZ6Y3KW to complete...
# Task BEXRZKWY2OHOKLWZHDZ6Y3KW completed with status {'state': 'COMPLETED', 'description': 'elevation_12', 'creation_timestamp_ms': 1692070791369, 'update_timestamp_ms': 1692070852760, 'start_timestamp_ms': 1692070831399, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14852644503116608, 'id': 'BEXRZKWY2OHOKLWZHDZ6Y3KW', 'name': 'projects/earthengine-legacy/operations/BEXRZKWY2OHOKLWZHDZ6Y3KW'}
# Waiting for task TOAK2FJMCTC3RZPUGAKPJSHQ to complete...
# Task TOAK2FJMCTC3RZPUGAKPJSHQ completed with status {'state': 'COMPLETED', 'description': 'elevation_13', 'creation_timestamp_ms': 1692070792703, 'update_timestamp_ms': 1692070856434, 'start_timestamp_ms': 1692070842102, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.17366191744804382, 'id': 'TOAK2FJMCTC3RZPUGAKPJSHQ', 'name': 'projects/earthengine-legacy/operations/TOAK2FJMCTC3RZPUGAKPJSHQ'}
# Waiting for task FRSUQQJG4B3EZHK4EBNYFNWP to complete...
# Task FRSUQQJG4B3EZHK4EBNYFNWP completed with status {'state': 'COMPLETED', 'description': 'elevation_14', 'creation_timestamp_ms': 1692070794293, 'update_timestamp_ms': 1692070863711, 'start_timestamp_ms': 1692070852579, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2135879397392273, 'id': 'FRSUQQJG4B3EZHK4EBNYFNWP', 'name': 'projects/earthengine-legacy/operations/FRSUQQJG4B3EZHK4EBNYFNWP'}
# Waiting for task IDAZENJXOO76UEWEEXR35FFE to complete...
# Task IDAZENJXOO76UEWEEXR35FFE completed with status {'state': 'COMPLETED', 'description': 'elevation_15', 'creation_timestamp_ms': 1692070795757, 'update_timestamp_ms': 1692070859898, 'start_timestamp_ms': 1692070852581, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.32721370458602905, 'id': 'IDAZENJXOO76UEWEEXR35FFE', 'name': 'projects/earthengine-legacy/operations/IDAZENJXOO76UEWEEXR35FFE'}
# Waiting for task FUHNNGLMY4SUPI6H5YFQNIXA to complete...
# Task FUHNNGLMY4SUPI6H5YFQNIXA completed with status {'state': 'COMPLETED', 'description': 'elevation_16', 'creation_timestamp_ms': 1692070797093, 'update_timestamp_ms': 1692070868812, 'start_timestamp_ms': 1692070861986, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14561669528484344, 'id': 'FUHNNGLMY4SUPI6H5YFQNIXA', 'name': 'projects/earthengine-legacy/operations/FUHNNGLMY4SUPI6H5YFQNIXA'}
# Waiting for task RBYE5GMTRLEYWEIBP6BJBUBF to complete...
# Task RBYE5GMTRLEYWEIBP6BJBUBF completed with status {'state': 'COMPLETED', 'description': 'elevation_17', 'creation_timestamp_ms': 1692070798411, 'update_timestamp_ms': 1692070869467, 'start_timestamp_ms': 1692070861985, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.28104594349861145, 'id': 'RBYE5GMTRLEYWEIBP6BJBUBF', 'name': 'projects/earthengine-legacy/operations/RBYE5GMTRLEYWEIBP6BJBUBF'}
# Waiting for task LP6CXCPNPW4ML73G4AAT7H6E to complete...
# Task LP6CXCPNPW4ML73G4AAT7H6E completed with status {'state': 'COMPLETED', 'description': 'elevation_18', 'creation_timestamp_ms': 1692070799972, 'update_timestamp_ms': 1692070880623, 'start_timestamp_ms': 1692070872349, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14250381290912628, 'id': 'LP6CXCPNPW4ML73G4AAT7H6E', 'name': 'projects/earthengine-legacy/operations/LP6CXCPNPW4ML73G4AAT7H6E'}
# Waiting for task PRKW34DHY3M2F7ETIBKUV5LO to complete...
# Task PRKW34DHY3M2F7ETIBKUV5LO completed with status {'state': 'COMPLETED', 'description': 'elevation_19', 'creation_timestamp_ms': 1692070801355, 'update_timestamp_ms': 1692070879423, 'start_timestamp_ms': 1692070872346, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.10161245614290237, 'id': 'PRKW34DHY3M2F7ETIBKUV5LO', 'name': 'projects/earthengine-legacy/operations/PRKW34DHY3M2F7ETIBKUV5LO'}
# Waiting for task AKLPCH6UUL7XDEXJLRTSRQHI to complete...
# Task AKLPCH6UUL7XDEXJLRTSRQHI completed with status {'state': 'COMPLETED', 'description': 'elevation_20', 'creation_timestamp_ms': 1692070802589, 'update_timestamp_ms': 1692070889243, 'start_timestamp_ms': 1692070881537, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.3362205922603607, 'id': 'AKLPCH6UUL7XDEXJLRTSRQHI', 'name': 'projects/earthengine-legacy/operations/AKLPCH6UUL7XDEXJLRTSRQHI'}
# Waiting for task QMNLN626MBUD5YPYAIPVK6ZW to complete...
# Task QMNLN626MBUD5YPYAIPVK6ZW completed with status {'state': 'COMPLETED', 'description': 'elevation_21', 'creation_timestamp_ms': 1692070803957, 'update_timestamp_ms': 1692070889673, 'start_timestamp_ms': 1692070881532, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.19560588896274567, 'id': 'QMNLN626MBUD5YPYAIPVK6ZW', 'name': 'projects/earthengine-legacy/operations/QMNLN626MBUD5YPYAIPVK6ZW'}
# Waiting for task SUQQXCCWIEX5QOTPJ6ZQIQ4M to complete...
# Task SUQQXCCWIEX5QOTPJ6ZQIQ4M completed with status {'state': 'COMPLETED', 'description': 'elevation_22', 'creation_timestamp_ms': 1692070805233, 'update_timestamp_ms': 1692070905558, 'start_timestamp_ms': 1692070891604, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.4815155863761902, 'id': 'SUQQXCCWIEX5QOTPJ6ZQIQ4M', 'name': 'projects/earthengine-legacy/operations/SUQQXCCWIEX5QOTPJ6ZQIQ4M'}
# Waiting for task JF45N3Q2AQJL24GIMOU5C4TE to complete...
# Task JF45N3Q2AQJL24GIMOU5C4TE completed with status {'state': 'COMPLETED', 'description': 'elevation_23', 'creation_timestamp_ms': 1692070806411, 'update_timestamp_ms': 1692070899375, 'start_timestamp_ms': 1692070891601, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.23251748085021973, 'id': 'JF45N3Q2AQJL24GIMOU5C4TE', 'name': 'projects/earthengine-legacy/operations/JF45N3Q2AQJL24GIMOU5C4TE'}
# Waiting for task W3RME32L5ENRLNNV2EJUYCLR to complete...
# Task W3RME32L5ENRLNNV2EJUYCLR completed with status {'state': 'COMPLETED', 'description': 'elevation_24', 'creation_timestamp_ms': 1692070807820, 'update_timestamp_ms': 1692070909030, 'start_timestamp_ms': 1692070902338, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1198287084698677, 'id': 'W3RME32L5ENRLNNV2EJUYCLR', 'name': 'projects/earthengine-legacy/operations/W3RME32L5ENRLNNV2EJUYCLR'}
# Waiting for task UMGMJEHSYMI4DUW55AV3XMGR to complete...
# Task UMGMJEHSYMI4DUW55AV3XMGR completed with status {'state': 'COMPLETED', 'description': 'elevation_25', 'creation_timestamp_ms': 1692070809016, 'update_timestamp_ms': 1692070911637, 'start_timestamp_ms': 1692070902336, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.3517058193683624, 'id': 'UMGMJEHSYMI4DUW55AV3XMGR', 'name': 'projects/earthengine-legacy/operations/UMGMJEHSYMI4DUW55AV3XMGR'}
# Waiting for task 3QTTJFY4AG346FCIPAK46XH2 to complete...
# Task 3QTTJFY4AG346FCIPAK46XH2 completed with status {'state': 'COMPLETED', 'description': 'elevation_26', 'creation_timestamp_ms': 1692070810437, 'update_timestamp_ms': 1692070919691, 'start_timestamp_ms': 1692070911454, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.22157573699951172, 'id': '3QTTJFY4AG346FCIPAK46XH2', 'name': 'projects/earthengine-legacy/operations/3QTTJFY4AG346FCIPAK46XH2'}
# Waiting for task WBN7MUIDJK6LUZYQ5673XD7M to complete...
# Task WBN7MUIDJK6LUZYQ5673XD7M completed with status {'state': 'COMPLETED', 'description': 'elevation_27', 'creation_timestamp_ms': 1692070811611, 'update_timestamp_ms': 1692070918443, 'start_timestamp_ms': 1692070911456, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.3401823043823242, 'id': 'WBN7MUIDJK6LUZYQ5673XD7M', 'name': 'projects/earthengine-legacy/operations/WBN7MUIDJK6LUZYQ5673XD7M'}
# Waiting for task RLTRSQ4HYQU4XL4QGC5ZSHM5 to complete...
# Task RLTRSQ4HYQU4XL4QGC5ZSHM5 completed with status {'state': 'COMPLETED', 'description': 'elevation_28', 'creation_timestamp_ms': 1692070812982, 'update_timestamp_ms': 1692070933964, 'start_timestamp_ms': 1692070922438, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.17237205803394318, 'id': 'RLTRSQ4HYQU4XL4QGC5ZSHM5', 'name': 'projects/earthengine-legacy/operations/RLTRSQ4HYQU4XL4QGC5ZSHM5'}
# Waiting for task 67R5OWSCTH4TRSNJV5A4KADH to complete...
# Task 67R5OWSCTH4TRSNJV5A4KADH completed with status {'state': 'COMPLETED', 'description': 'elevation_29', 'creation_timestamp_ms': 1692070814225, 'update_timestamp_ms': 1692070940128, 'start_timestamp_ms': 1692070922434, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.20469814538955688, 'id': '67R5OWSCTH4TRSNJV5A4KADH', 'name': 'projects/earthengine-legacy/operations/67R5OWSCTH4TRSNJV5A4KADH'}
# Waiting for task ITH5MH5EXPSBBWPOLMZZFK4L to complete...
# Task ITH5MH5EXPSBBWPOLMZZFK4L completed with status {'state': 'COMPLETED', 'description': 'elevation_30', 'creation_timestamp_ms': 1692070815758, 'update_timestamp_ms': 1692070933609, 'start_timestamp_ms': 1692070922429, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.17384403944015503, 'id': 'ITH5MH5EXPSBBWPOLMZZFK4L', 'name': 'projects/earthengine-legacy/operations/ITH5MH5EXPSBBWPOLMZZFK4L'}
# Waiting for task HHHAKCRDYQGDIUNO2YBFNCA7 to complete...
# Task HHHAKCRDYQGDIUNO2YBFNCA7 completed with status {'state': 'COMPLETED', 'description': 'elevation_31', 'creation_timestamp_ms': 1692070817201, 'update_timestamp_ms': 1692070950956, 'start_timestamp_ms': 1692070942063, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1477382630109787, 'id': 'HHHAKCRDYQGDIUNO2YBFNCA7', 'name': 'projects/earthengine-legacy/operations/HHHAKCRDYQGDIUNO2YBFNCA7'}
# Waiting for task RF35QY6IL3U7JCHU4OIF7E6N to complete...
# Task RF35QY6IL3U7JCHU4OIF7E6N completed with status {'state': 'COMPLETED', 'description': 'elevation_32', 'creation_timestamp_ms': 1692070818417, 'update_timestamp_ms': 1692070951708, 'start_timestamp_ms': 1692070942054, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2579064667224884, 'id': 'RF35QY6IL3U7JCHU4OIF7E6N', 'name': 'projects/earthengine-legacy/operations/RF35QY6IL3U7JCHU4OIF7E6N'}
# Waiting for task GPYODZOEPO6NHXFGX7LCJMCH to complete...
# Task GPYODZOEPO6NHXFGX7LCJMCH completed with status {'state': 'COMPLETED', 'description': 'elevation_33', 'creation_timestamp_ms': 1692070819721, 'update_timestamp_ms': 1692070951293, 'start_timestamp_ms': 1692070942057, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2633405327796936, 'id': 'GPYODZOEPO6NHXFGX7LCJMCH', 'name': 'projects/earthengine-legacy/operations/GPYODZOEPO6NHXFGX7LCJMCH'}
# Waiting for task 43IAF6CD3A4DKRZMDAWYDSFZ to complete...
# Task 43IAF6CD3A4DKRZMDAWYDSFZ completed with status {'state': 'COMPLETED', 'description': 'elevation_34', 'creation_timestamp_ms': 1692070820873, 'update_timestamp_ms': 1692070962907, 'start_timestamp_ms': 1692070952005, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.15310987830162048, 'id': '43IAF6CD3A4DKRZMDAWYDSFZ', 'name': 'projects/earthengine-legacy/operations/43IAF6CD3A4DKRZMDAWYDSFZ'}
# Waiting for task 3GKGKH5MFUEXCGCQ4GYNI6DO to complete...
# Task 3GKGKH5MFUEXCGCQ4GYNI6DO completed with status {'state': 'COMPLETED', 'description': 'elevation_35', 'creation_timestamp_ms': 1692070822081, 'update_timestamp_ms': 1692070969704, 'start_timestamp_ms': 1692070961478, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.16941355168819427, 'id': '3GKGKH5MFUEXCGCQ4GYNI6DO', 'name': 'projects/earthengine-legacy/operations/3GKGKH5MFUEXCGCQ4GYNI6DO'}
# Waiting for task OKNRMUCOQ6P7FKBUZCHZCDEY to complete...
# Task OKNRMUCOQ6P7FKBUZCHZCDEY completed with status {'state': 'COMPLETED', 'description': 'elevation_36', 'creation_timestamp_ms': 1692070823511, 'update_timestamp_ms': 1692070968400, 'start_timestamp_ms': 1692070961471, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1606655865907669, 'id': 'OKNRMUCOQ6P7FKBUZCHZCDEY', 'name': 'projects/earthengine-legacy/operations/OKNRMUCOQ6P7FKBUZCHZCDEY'}
# Waiting for task FDDOK5HM7QGBLPGUBPWWQSST to complete...
# Task FDDOK5HM7QGBLPGUBPWWQSST completed with status {'state': 'COMPLETED', 'description': 'elevation_37', 'creation_timestamp_ms': 1692070824546, 'update_timestamp_ms': 1692070968708, 'start_timestamp_ms': 1692070961465, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14045597612857819, 'id': 'FDDOK5HM7QGBLPGUBPWWQSST', 'name': 'projects/earthengine-legacy/operations/FDDOK5HM7QGBLPGUBPWWQSST'}
# Waiting for task 5XHWI2QJNPKVNN54XLBKAQDH to complete...
# Task 5XHWI2QJNPKVNN54XLBKAQDH completed with status {'state': 'COMPLETED', 'description': 'elevation_38', 'creation_timestamp_ms': 1692070825750, 'update_timestamp_ms': 1692070979787, 'start_timestamp_ms': 1692070972309, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.19738870859146118, 'id': '5XHWI2QJNPKVNN54XLBKAQDH', 'name': 'projects/earthengine-legacy/operations/5XHWI2QJNPKVNN54XLBKAQDH'}
# Waiting for task C6DNDU2BQ5UUL423MV7TMRUE to complete...
# Task C6DNDU2BQ5UUL423MV7TMRUE completed with status {'state': 'COMPLETED', 'description': 'elevation_39', 'creation_timestamp_ms': 1692070827142, 'update_timestamp_ms': 1692070980320, 'start_timestamp_ms': 1692070972308, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1764974743127823, 'id': 'C6DNDU2BQ5UUL423MV7TMRUE', 'name': 'projects/earthengine-legacy/operations/C6DNDU2BQ5UUL423MV7TMRUE'}
# Waiting for task WTQWAQCYAHQZI5E7F3JFIRBF to complete...
# Task WTQWAQCYAHQZI5E7F3JFIRBF completed with status {'state': 'COMPLETED', 'description': 'elevation_40', 'creation_timestamp_ms': 1692070828360, 'update_timestamp_ms': 1692070979191, 'start_timestamp_ms': 1692070972305, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1313782036304474, 'id': 'WTQWAQCYAHQZI5E7F3JFIRBF', 'name': 'projects/earthengine-legacy/operations/WTQWAQCYAHQZI5E7F3JFIRBF'}
# Waiting for task 7I2DQIAYSB3337NYXYWOCXMV to complete...
# Task 7I2DQIAYSB3337NYXYWOCXMV completed with status {'state': 'COMPLETED', 'description': 'elevation_41', 'creation_timestamp_ms': 1692070829636, 'update_timestamp_ms': 1692070992796, 'start_timestamp_ms': 1692070981525, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.27959585189819336, 'id': '7I2DQIAYSB3337NYXYWOCXMV', 'name': 'projects/earthengine-legacy/operations/7I2DQIAYSB3337NYXYWOCXMV'}
# Waiting for task DKY5DIUYAAEG3FDNFKPVMNTI to complete...
# Task DKY5DIUYAAEG3FDNFKPVMNTI completed with status {'state': 'COMPLETED', 'description': 'elevation_42', 'creation_timestamp_ms': 1692070830899, 'update_timestamp_ms': 1692070999957, 'start_timestamp_ms': 1692070991622, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14639736711978912, 'id': 'DKY5DIUYAAEG3FDNFKPVMNTI', 'name': 'projects/earthengine-legacy/operations/DKY5DIUYAAEG3FDNFKPVMNTI'}
# Waiting for task QE27KGCCRMM6E6GNCIM4EXD2 to complete...
# Task QE27KGCCRMM6E6GNCIM4EXD2 completed with status {'state': 'COMPLETED', 'description': 'elevation_43', 'creation_timestamp_ms': 1692070832248, 'update_timestamp_ms': 1692071003170, 'start_timestamp_ms': 1692070991616, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1767888069152832, 'id': 'QE27KGCCRMM6E6GNCIM4EXD2', 'name': 'projects/earthengine-legacy/operations/QE27KGCCRMM6E6GNCIM4EXD2'}
# Waiting for task JXDZSXGLHZSQRGDAG42N2NWF to complete...
# Task JXDZSXGLHZSQRGDAG42N2NWF completed with status {'state': 'COMPLETED', 'description': 'elevation_44', 'creation_timestamp_ms': 1692070833488, 'update_timestamp_ms': 1692071005876, 'start_timestamp_ms': 1692070991614, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.20868250727653503, 'id': 'JXDZSXGLHZSQRGDAG42N2NWF', 'name': 'projects/earthengine-legacy/operations/JXDZSXGLHZSQRGDAG42N2NWF'}
# Waiting for task SUIEYBX4CIWTE7BM7QPI7L7G to complete...
# Task SUIEYBX4CIWTE7BM7QPI7L7G completed with status {'state': 'COMPLETED', 'description': 'elevation_45', 'creation_timestamp_ms': 1692070834662, 'update_timestamp_ms': 1692071010647, 'start_timestamp_ms': 1692071002088, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1231733113527298, 'id': 'SUIEYBX4CIWTE7BM7QPI7L7G', 'name': 'projects/earthengine-legacy/operations/SUIEYBX4CIWTE7BM7QPI7L7G'}
# Waiting for task HBQVHKFR4T3GZFKWREFL4A6V to complete...
# Task HBQVHKFR4T3GZFKWREFL4A6V completed with status {'state': 'COMPLETED', 'description': 'elevation_46', 'creation_timestamp_ms': 1692070836015, 'update_timestamp_ms': 1692071020179, 'start_timestamp_ms': 1692071012177, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.16023027896881104, 'id': 'HBQVHKFR4T3GZFKWREFL4A6V', 'name': 'projects/earthengine-legacy/operations/HBQVHKFR4T3GZFKWREFL4A6V'}
# Waiting for task KKCBNQYNOS57T4F6HQOCUYGM to complete...
# Task KKCBNQYNOS57T4F6HQOCUYGM completed with status {'state': 'COMPLETED', 'description': 'elevation_47', 'creation_timestamp_ms': 1692070837151, 'update_timestamp_ms': 1692071034028, 'start_timestamp_ms': 1692071012172, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2044694572687149, 'id': 'KKCBNQYNOS57T4F6HQOCUYGM', 'name': 'projects/earthengine-legacy/operations/KKCBNQYNOS57T4F6HQOCUYGM'}
# Waiting for task G5SPYFHYSZC5Y6FDLT7WR3NW to complete...
# Task G5SPYFHYSZC5Y6FDLT7WR3NW completed with status {'state': 'COMPLETED', 'description': 'elevation_48', 'creation_timestamp_ms': 1692070838312, 'update_timestamp_ms': 1692071020707, 'start_timestamp_ms': 1692071012168, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2602294087409973, 'id': 'G5SPYFHYSZC5Y6FDLT7WR3NW', 'name': 'projects/earthengine-legacy/operations/G5SPYFHYSZC5Y6FDLT7WR3NW'}
# Waiting for task FXFOBP77JCBV4YJE2VX4H2XQ to complete...
# Task FXFOBP77JCBV4YJE2VX4H2XQ completed with status {'state': 'COMPLETED', 'description': 'elevation_49', 'creation_timestamp_ms': 1692070839490, 'update_timestamp_ms': 1692071029665, 'start_timestamp_ms': 1692071021748, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.13943935930728912, 'id': 'FXFOBP77JCBV4YJE2VX4H2XQ', 'name': 'projects/earthengine-legacy/operations/FXFOBP77JCBV4YJE2VX4H2XQ'}
# Waiting for task ORENBDGEXRWWBDWURE2SBC5B to complete...
# Task ORENBDGEXRWWBDWURE2SBC5B completed with status {'state': 'COMPLETED', 'description': 'elevation_50', 'creation_timestamp_ms': 1692070840801, 'update_timestamp_ms': 1692071038401, 'start_timestamp_ms': 1692071031617, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.16368576884269714, 'id': 'ORENBDGEXRWWBDWURE2SBC5B', 'name': 'projects/earthengine-legacy/operations/ORENBDGEXRWWBDWURE2SBC5B'}
# Waiting for task SA4U4NUVWPQALTS6EHYNM2SH to complete...
# Task SA4U4NUVWPQALTS6EHYNM2SH completed with status {'state': 'COMPLETED', 'description': 'elevation_51', 'creation_timestamp_ms': 1692070842007, 'update_timestamp_ms': 1692071039924, 'start_timestamp_ms': 1692071031611, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.21716102957725525, 'id': 'SA4U4NUVWPQALTS6EHYNM2SH', 'name': 'projects/earthengine-legacy/operations/SA4U4NUVWPQALTS6EHYNM2SH'}
# Waiting for task J322ALN7NPOXA3DY5EQS6FJ4 to complete...
# Task J322ALN7NPOXA3DY5EQS6FJ4 completed with status {'state': 'COMPLETED', 'description': 'elevation_52', 'creation_timestamp_ms': 1692070843414, 'update_timestamp_ms': 1692071053625, 'start_timestamp_ms': 1692071041648, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.21184974908828735, 'id': 'J322ALN7NPOXA3DY5EQS6FJ4', 'name': 'projects/earthengine-legacy/operations/J322ALN7NPOXA3DY5EQS6FJ4'}
# Waiting for task UCGUPG3C26B2T3VAHTLTUSV7 to complete...
# Task UCGUPG3C26B2T3VAHTLTUSV7 completed with status {'state': 'COMPLETED', 'description': 'elevation_53', 'creation_timestamp_ms': 1692070844625, 'update_timestamp_ms': 1692071049420, 'start_timestamp_ms': 1692071041640, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.15719906985759735, 'id': 'UCGUPG3C26B2T3VAHTLTUSV7', 'name': 'projects/earthengine-legacy/operations/UCGUPG3C26B2T3VAHTLTUSV7'}
# Waiting for task VD52AFOGQCNFHPO3XXXGIKER to complete...
# Task VD52AFOGQCNFHPO3XXXGIKER completed with status {'state': 'COMPLETED', 'description': 'elevation_54', 'creation_timestamp_ms': 1692070845989, 'update_timestamp_ms': 1692071048516, 'start_timestamp_ms': 1692071041637, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.15629462897777557, 'id': 'VD52AFOGQCNFHPO3XXXGIKER', 'name': 'projects/earthengine-legacy/operations/VD52AFOGQCNFHPO3XXXGIKER'}
# Waiting for task Y7WXEE3UK2YM7CXTDARNRQ75 to complete...
# Task Y7WXEE3UK2YM7CXTDARNRQ75 completed with status {'state': 'COMPLETED', 'description': 'elevation_55', 'creation_timestamp_ms': 1692070847120, 'update_timestamp_ms': 1692071058533, 'start_timestamp_ms': 1692071051631, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14612045884132385, 'id': 'Y7WXEE3UK2YM7CXTDARNRQ75', 'name': 'projects/earthengine-legacy/operations/Y7WXEE3UK2YM7CXTDARNRQ75'}
# Waiting for task RG36PPOEW5CUVQCPU3GTK2XG to complete...
# Task RG36PPOEW5CUVQCPU3GTK2XG completed with status {'state': 'COMPLETED', 'description': 'elevation_56', 'creation_timestamp_ms': 1692070848320, 'update_timestamp_ms': 1692071060381, 'start_timestamp_ms': 1692071051627, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.3081783056259155, 'id': 'RG36PPOEW5CUVQCPU3GTK2XG', 'name': 'projects/earthengine-legacy/operations/RG36PPOEW5CUVQCPU3GTK2XG'}
# Waiting for task DK4MIQA2OFOH6VFXFQDHVWPA to complete...
# Task DK4MIQA2OFOH6VFXFQDHVWPA completed with status {'state': 'COMPLETED', 'description': 'elevation_57', 'creation_timestamp_ms': 1692070849699, 'update_timestamp_ms': 1692071068506, 'start_timestamp_ms': 1692071061595, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1598084419965744, 'id': 'DK4MIQA2OFOH6VFXFQDHVWPA', 'name': 'projects/earthengine-legacy/operations/DK4MIQA2OFOH6VFXFQDHVWPA'}
# Waiting for task EXFMZCLKZJBBGVZREOY4ENJX to complete...
# Task EXFMZCLKZJBBGVZREOY4ENJX completed with status {'state': 'COMPLETED', 'description': 'elevation_58', 'creation_timestamp_ms': 1692070850892, 'update_timestamp_ms': 1692071069606, 'start_timestamp_ms': 1692071061593, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.16578075289726257, 'id': 'EXFMZCLKZJBBGVZREOY4ENJX', 'name': 'projects/earthengine-legacy/operations/EXFMZCLKZJBBGVZREOY4ENJX'}
# Waiting for task DMMJJ36R2E7NDGRUO2DW5EYL to complete...
# Task DMMJJ36R2E7NDGRUO2DW5EYL completed with status {'state': 'COMPLETED', 'description': 'elevation_59', 'creation_timestamp_ms': 1692070852214, 'update_timestamp_ms': 1692071069964, 'start_timestamp_ms': 1692071061591, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.16957928240299225, 'id': 'DMMJJ36R2E7NDGRUO2DW5EYL', 'name': 'projects/earthengine-legacy/operations/DMMJJ36R2E7NDGRUO2DW5EYL'}
# Waiting for task H2OM756UKUD5VRCQEVGYMRZJ to complete...
# Task H2OM756UKUD5VRCQEVGYMRZJ completed with status {'state': 'COMPLETED', 'description': 'elevation_60', 'creation_timestamp_ms': 1692070853480, 'update_timestamp_ms': 1692071078728, 'start_timestamp_ms': 1692071071665, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.19591505825519562, 'id': 'H2OM756UKUD5VRCQEVGYMRZJ', 'name': 'projects/earthengine-legacy/operations/H2OM756UKUD5VRCQEVGYMRZJ'}
# Waiting for task YI6EEGP2JNQHGC2QTFRLVZOF to complete...
# Task YI6EEGP2JNQHGC2QTFRLVZOF completed with status {'state': 'COMPLETED', 'description': 'elevation_61', 'creation_timestamp_ms': 1692070854637, 'update_timestamp_ms': 1692071082541, 'start_timestamp_ms': 1692071071663, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.20061591267585754, 'id': 'YI6EEGP2JNQHGC2QTFRLVZOF', 'name': 'projects/earthengine-legacy/operations/YI6EEGP2JNQHGC2QTFRLVZOF'}
# Waiting for task JO5A77EG6S5467GLLPCRV3RE to complete...
# Task JO5A77EG6S5467GLLPCRV3RE completed with status {'state': 'COMPLETED', 'description': 'elevation_62', 'creation_timestamp_ms': 1692070856008, 'update_timestamp_ms': 1692071089743, 'start_timestamp_ms': 1692071082293, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1687474250793457, 'id': 'JO5A77EG6S5467GLLPCRV3RE', 'name': 'projects/earthengine-legacy/operations/JO5A77EG6S5467GLLPCRV3RE'}
# Waiting for task WUR3F34RLNOPPZUWT5F3CZ4V to complete...
# Task WUR3F34RLNOPPZUWT5F3CZ4V completed with status {'state': 'COMPLETED', 'description': 'elevation_63', 'creation_timestamp_ms': 1692070857226, 'update_timestamp_ms': 1692071089340, 'start_timestamp_ms': 1692071082290, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1487717628479004, 'id': 'WUR3F34RLNOPPZUWT5F3CZ4V', 'name': 'projects/earthengine-legacy/operations/WUR3F34RLNOPPZUWT5F3CZ4V'}
# Waiting for task K2Z2MYMFUOSMPXUVDY42A6DI to complete...
# Task K2Z2MYMFUOSMPXUVDY42A6DI completed with status {'state': 'COMPLETED', 'description': 'elevation_64', 'creation_timestamp_ms': 1692070858626, 'update_timestamp_ms': 1692071090121, 'start_timestamp_ms': 1692071082291, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14791236817836761, 'id': 'K2Z2MYMFUOSMPXUVDY42A6DI', 'name': 'projects/earthengine-legacy/operations/K2Z2MYMFUOSMPXUVDY42A6DI'}
# Waiting for task IVUU4BAKW257SZQ3FWE2QVVW to complete...
# Task IVUU4BAKW257SZQ3FWE2QVVW completed with status {'state': 'COMPLETED', 'description': 'elevation_65', 'creation_timestamp_ms': 1692070859797, 'update_timestamp_ms': 1692071099796, 'start_timestamp_ms': 1692071091668, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.12148180603981018, 'id': 'IVUU4BAKW257SZQ3FWE2QVVW', 'name': 'projects/earthengine-legacy/operations/IVUU4BAKW257SZQ3FWE2QVVW'}
# Waiting for task HYLGNUO76YY745UON44N3ZOM to complete...
# Task HYLGNUO76YY745UON44N3ZOM completed with status {'state': 'COMPLETED', 'description': 'elevation_66', 'creation_timestamp_ms': 1692070861338, 'update_timestamp_ms': 1692071112085, 'start_timestamp_ms': 1692071102367, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.23440298438072205, 'id': 'HYLGNUO76YY745UON44N3ZOM', 'name': 'projects/earthengine-legacy/operations/HYLGNUO76YY745UON44N3ZOM'}
# Waiting for task SMW3T3FTS6QWWJ7ZPOZ7MVFW to complete...
# Task SMW3T3FTS6QWWJ7ZPOZ7MVFW completed with status {'state': 'COMPLETED', 'description': 'elevation_67', 'creation_timestamp_ms': 1692070862655, 'update_timestamp_ms': 1692071111605, 'start_timestamp_ms': 1692071102356, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.12782181799411774, 'id': 'SMW3T3FTS6QWWJ7ZPOZ7MVFW', 'name': 'projects/earthengine-legacy/operations/SMW3T3FTS6QWWJ7ZPOZ7MVFW'}
# Waiting for task ZUF6AGYLFR6XZHUF73HWTTZD to complete...
# Task ZUF6AGYLFR6XZHUF73HWTTZD completed with status {'state': 'COMPLETED', 'description': 'elevation_68', 'creation_timestamp_ms': 1692070864018, 'update_timestamp_ms': 1692071112530, 'start_timestamp_ms': 1692071102353, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.16309483349323273, 'id': 'ZUF6AGYLFR6XZHUF73HWTTZD', 'name': 'projects/earthengine-legacy/operations/ZUF6AGYLFR6XZHUF73HWTTZD'}
# Waiting for task WSOFXVUBRKGCUBZLNZ27ZJU4 to complete...
# Task WSOFXVUBRKGCUBZLNZ27ZJU4 completed with status {'state': 'COMPLETED', 'description': 'elevation_69', 'creation_timestamp_ms': 1692070865410, 'update_timestamp_ms': 1692071119689, 'start_timestamp_ms': 1692071111556, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1701785773038864, 'id': 'WSOFXVUBRKGCUBZLNZ27ZJU4', 'name': 'projects/earthengine-legacy/operations/WSOFXVUBRKGCUBZLNZ27ZJU4'}
# Waiting for task R4W3ASZ4OE2FCTZH5XCGAMUE to complete...
# Task R4W3ASZ4OE2FCTZH5XCGAMUE completed with status {'state': 'COMPLETED', 'description': 'elevation_70', 'creation_timestamp_ms': 1692070867633, 'update_timestamp_ms': 1692071130195, 'start_timestamp_ms': 1692071122102, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2045191079378128, 'id': 'R4W3ASZ4OE2FCTZH5XCGAMUE', 'name': 'projects/earthengine-legacy/operations/R4W3ASZ4OE2FCTZH5XCGAMUE'}
# Waiting for task 4MBPITU4RXDDDPIDT2MLP7FW to complete...
# Task 4MBPITU4RXDDDPIDT2MLP7FW completed with status {'state': 'COMPLETED', 'description': 'elevation_71', 'creation_timestamp_ms': 1692070869100, 'update_timestamp_ms': 1692071131256, 'start_timestamp_ms': 1692071122098, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14498481154441833, 'id': '4MBPITU4RXDDDPIDT2MLP7FW', 'name': 'projects/earthengine-legacy/operations/4MBPITU4RXDDDPIDT2MLP7FW'}
# Waiting for task 3WEPK7AXTJLC7BQI5Y3AH4CL to complete...
# Task 3WEPK7AXTJLC7BQI5Y3AH4CL completed with status {'state': 'COMPLETED', 'description': 'elevation_72', 'creation_timestamp_ms': 1692070870287, 'update_timestamp_ms': 1692071140304, 'start_timestamp_ms': 1692071122096, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.24517321586608887, 'id': '3WEPK7AXTJLC7BQI5Y3AH4CL', 'name': 'projects/earthengine-legacy/operations/3WEPK7AXTJLC7BQI5Y3AH4CL'}
# Waiting for task KDDXVNLHHEYD7MZKFWZNZCPT to complete...
# Task KDDXVNLHHEYD7MZKFWZNZCPT completed with status {'state': 'COMPLETED', 'description': 'elevation_73', 'creation_timestamp_ms': 1692070871781, 'update_timestamp_ms': 1692071139737, 'start_timestamp_ms': 1692071131510, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.18707576394081116, 'id': 'KDDXVNLHHEYD7MZKFWZNZCPT', 'name': 'projects/earthengine-legacy/operations/KDDXVNLHHEYD7MZKFWZNZCPT'}
# Waiting for task O4HLSLTDBPLQ677I4WXLICCF to complete...
# Task O4HLSLTDBPLQ677I4WXLICCF completed with status {'state': 'COMPLETED', 'description': 'elevation_74', 'creation_timestamp_ms': 1692070872931, 'update_timestamp_ms': 1692071154723, 'start_timestamp_ms': 1692071142410, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.5949451327323914, 'id': 'O4HLSLTDBPLQ677I4WXLICCF', 'name': 'projects/earthengine-legacy/operations/O4HLSLTDBPLQ677I4WXLICCF'}
# Waiting for task KKHKQLVMNC5VDTSHN42T6A3T to complete...
# Task KKHKQLVMNC5VDTSHN42T6A3T completed with status {'state': 'COMPLETED', 'description': 'elevation_75', 'creation_timestamp_ms': 1692070874307, 'update_timestamp_ms': 1692071153573, 'start_timestamp_ms': 1692071142404, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.18399779498577118, 'id': 'KKHKQLVMNC5VDTSHN42T6A3T', 'name': 'projects/earthengine-legacy/operations/KKHKQLVMNC5VDTSHN42T6A3T'}
# Waiting for task WZOCVZSVC4GWEBKR6CVLDJ2I to complete...
# Task WZOCVZSVC4GWEBKR6CVLDJ2I completed with status {'state': 'COMPLETED', 'description': 'elevation_76', 'creation_timestamp_ms': 1692070875525, 'update_timestamp_ms': 1692071160175, 'start_timestamp_ms': 1692071152204, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.10584552586078644, 'id': 'WZOCVZSVC4GWEBKR6CVLDJ2I', 'name': 'projects/earthengine-legacy/operations/WZOCVZSVC4GWEBKR6CVLDJ2I'}
# Waiting for task TQCQOBHON225HUJKM6PNDNWI to complete...
# Task TQCQOBHON225HUJKM6PNDNWI completed with status {'state': 'COMPLETED', 'description': 'elevation_77', 'creation_timestamp_ms': 1692070876881, 'update_timestamp_ms': 1692071160642, 'start_timestamp_ms': 1692071152198, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1280144900083542, 'id': 'TQCQOBHON225HUJKM6PNDNWI', 'name': 'projects/earthengine-legacy/operations/TQCQOBHON225HUJKM6PNDNWI'}
# Waiting for task KRNALXMJBJUCDNAYO2GYIHGG to complete...
# Task KRNALXMJBJUCDNAYO2GYIHGG completed with status {'state': 'COMPLETED', 'description': 'elevation_78', 'creation_timestamp_ms': 1692070878058, 'update_timestamp_ms': 1692071170279, 'start_timestamp_ms': 1692071162230, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2193872481584549, 'id': 'KRNALXMJBJUCDNAYO2GYIHGG', 'name': 'projects/earthengine-legacy/operations/KRNALXMJBJUCDNAYO2GYIHGG'}
# Waiting for task 3GKWO2NG5CCZEXS3MJ3VW4NC to complete...
# Task 3GKWO2NG5CCZEXS3MJ3VW4NC completed with status {'state': 'COMPLETED', 'description': 'elevation_79', 'creation_timestamp_ms': 1692070879208, 'update_timestamp_ms': 1692071169279, 'start_timestamp_ms': 1692071162233, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.2903866767883301, 'id': '3GKWO2NG5CCZEXS3MJ3VW4NC', 'name': 'projects/earthengine-legacy/operations/3GKWO2NG5CCZEXS3MJ3VW4NC'}
# Waiting for task NPGJI2MBPBKTW3TMXFX45B44 to complete...
# Task NPGJI2MBPBKTW3TMXFX45B44 completed with status {'state': 'COMPLETED', 'description': 'elevation_80', 'creation_timestamp_ms': 1692070880748, 'update_timestamp_ms': 1692071179830, 'start_timestamp_ms': 1692071172630, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.21601611375808716, 'id': 'NPGJI2MBPBKTW3TMXFX45B44', 'name': 'projects/earthengine-legacy/operations/NPGJI2MBPBKTW3TMXFX45B44'}
# Waiting for task SBKDCFRHJE5A3U2KC5O4ILME to complete...
# Task SBKDCFRHJE5A3U2KC5O4ILME completed with status {'state': 'COMPLETED', 'description': 'elevation_81', 'creation_timestamp_ms': 1692070882003, 'update_timestamp_ms': 1692071180844, 'start_timestamp_ms': 1692071172631, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1278693974018097, 'id': 'SBKDCFRHJE5A3U2KC5O4ILME', 'name': 'projects/earthengine-legacy/operations/SBKDCFRHJE5A3U2KC5O4ILME'}
# Waiting for task 7WVOTXHL6P6PWDB7CLZML2MY to complete...
# Task 7WVOTXHL6P6PWDB7CLZML2MY completed with status {'state': 'COMPLETED', 'description': 'elevation_82', 'creation_timestamp_ms': 1692070883342, 'update_timestamp_ms': 1692071189607, 'start_timestamp_ms': 1692071181730, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1406404823064804, 'id': '7WVOTXHL6P6PWDB7CLZML2MY', 'name': 'projects/earthengine-legacy/operations/7WVOTXHL6P6PWDB7CLZML2MY'}
# Waiting for task 2OGF5MU3J2QR4ITI5GBJYT4S to complete...
# ...
# Waiting for task BZPPAW5FLVGDLXAO2LBLNSWE to complete...
# Task BZPPAW5FLVGDLXAO2LBLNSWE completed with status {'state': 'COMPLETED', 'description': 'elevation_1973', 'creation_timestamp_ms': 1692073365519, 'update_timestamp_ms': 1692080881626, 'start_timestamp_ms': 1692080874454, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.11596077680587769, 'id': 'BZPPAW5FLVGDLXAO2LBLNSWE', 'name': 'projects/earthengine-legacy/operations/BZPPAW5FLVGDLXAO2LBLNSWE'}
# Waiting for task AKCA4GAY2QTZZSMGGOYI2LVI to complete...
# Task AKCA4GAY2QTZZSMGGOYI2LVI completed with status {'state': 'COMPLETED', 'description': 'elevation_1974', 'creation_timestamp_ms': 1692073366817, 'update_timestamp_ms': 1692080891291, 'start_timestamp_ms': 1692080884442, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.130549818277359, 'id': 'AKCA4GAY2QTZZSMGGOYI2LVI', 'name': 'projects/earthengine-legacy/operations/AKCA4GAY2QTZZSMGGOYI2LVI'}
# Waiting for task CQL5FQGXPE5TS35PK7LOVPIO to complete...
# Task CQL5FQGXPE5TS35PK7LOVPIO completed with status {'state': 'COMPLETED', 'description': 'elevation_1975', 'creation_timestamp_ms': 1692073367821, 'update_timestamp_ms': 1692080928386, 'start_timestamp_ms': 1692080884445, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 1.7827900648117065, 'id': 'CQL5FQGXPE5TS35PK7LOVPIO', 'name': 'projects/earthengine-legacy/operations/CQL5FQGXPE5TS35PK7LOVPIO'}
# Waiting for task JTG6KYYWVLEPORFV6NC32CZW to complete...
# Task JTG6KYYWVLEPORFV6NC32CZW completed with status {'state': 'COMPLETED', 'description': 'elevation_1976', 'creation_timestamp_ms': 1692073368837, 'update_timestamp_ms': 1692080901228, 'start_timestamp_ms': 1692080894348, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1587280035018921, 'id': 'JTG6KYYWVLEPORFV6NC32CZW', 'name': 'projects/earthengine-legacy/operations/JTG6KYYWVLEPORFV6NC32CZW'}
# Waiting for task MH6GQB3UMFKX5GDUERMGWWPO to complete...
# Task MH6GQB3UMFKX5GDUERMGWWPO completed with status {'state': 'COMPLETED', 'description': 'elevation_1977', 'creation_timestamp_ms': 1692073370045, 'update_timestamp_ms': 1692080904075, 'start_timestamp_ms': 1692080894350, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14652740955352783, 'id': 'MH6GQB3UMFKX5GDUERMGWWPO', 'name': 'projects/earthengine-legacy/operations/MH6GQB3UMFKX5GDUERMGWWPO'}
# Waiting for task M2GDJTLPJZYCKFFA3DUX24QY to complete...
# Task M2GDJTLPJZYCKFFA3DUX24QY completed with status {'state': 'COMPLETED', 'description': 'elevation_1978', 'creation_timestamp_ms': 1692073371541, 'update_timestamp_ms': 1692080916043, 'start_timestamp_ms': 1692080904470, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.08293012529611588, 'id': 'M2GDJTLPJZYCKFFA3DUX24QY', 'name': 'projects/earthengine-legacy/operations/M2GDJTLPJZYCKFFA3DUX24QY'}
# Waiting for task JX5Y2NJXDKWW2CB52FZVJRMO to complete...
# Task JX5Y2NJXDKWW2CB52FZVJRMO completed with status {'state': 'COMPLETED', 'description': 'elevation_1979', 'creation_timestamp_ms': 1692073373074, 'update_timestamp_ms': 1692080931230, 'start_timestamp_ms': 1692080914795, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14319872856140137, 'id': 'JX5Y2NJXDKWW2CB52FZVJRMO', 'name': 'projects/earthengine-legacy/operations/JX5Y2NJXDKWW2CB52FZVJRMO'}
# Waiting for task RKWNXA7CFZNSSOB6IOMG3NJH to complete...
# Task RKWNXA7CFZNSSOB6IOMG3NJH completed with status {'state': 'COMPLETED', 'description': 'elevation_1980', 'creation_timestamp_ms': 1692073374231, 'update_timestamp_ms': 1692080934772, 'start_timestamp_ms': 1692080914791, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.11872735619544983, 'id': 'RKWNXA7CFZNSSOB6IOMG3NJH', 'name': 'projects/earthengine-legacy/operations/RKWNXA7CFZNSSOB6IOMG3NJH'}
# Waiting for task B3WO52SJXG5GYACAJ7TBB66P to complete...
# Task B3WO52SJXG5GYACAJ7TBB66P completed with status {'state': 'COMPLETED', 'description': 'elevation_1981', 'creation_timestamp_ms': 1692073375658, 'update_timestamp_ms': 1692080933267, 'start_timestamp_ms': 1692080924686, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14148962497711182, 'id': 'B3WO52SJXG5GYACAJ7TBB66P', 'name': 'projects/earthengine-legacy/operations/B3WO52SJXG5GYACAJ7TBB66P'}
# Waiting for task TKH7AGWSL5C2UJYPU5SRCYT6 to complete...
# Task TKH7AGWSL5C2UJYPU5SRCYT6 completed with status {'state': 'COMPLETED', 'description': 'elevation_1982', 'creation_timestamp_ms': 1692073376853, 'update_timestamp_ms': 1692080944921, 'start_timestamp_ms': 1692080934649, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14673559367656708, 'id': 'TKH7AGWSL5C2UJYPU5SRCYT6', 'name': 'projects/earthengine-legacy/operations/TKH7AGWSL5C2UJYPU5SRCYT6'}
# Waiting for task PQMMFTFNT4HPJFRZ7KKRZNMI to complete...
# Task PQMMFTFNT4HPJFRZ7KKRZNMI completed with status {'state': 'COMPLETED', 'description': 'elevation_1983', 'creation_timestamp_ms': 1692073378300, 'update_timestamp_ms': 1692080951492, 'start_timestamp_ms': 1692080944469, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.144625723361969, 'id': 'PQMMFTFNT4HPJFRZ7KKRZNMI', 'name': 'projects/earthengine-legacy/operations/PQMMFTFNT4HPJFRZ7KKRZNMI'}
# Waiting for task PQIASEC3WJTWRDSO25TT2IJS to complete...
# Task PQIASEC3WJTWRDSO25TT2IJS completed with status {'state': 'COMPLETED', 'description': 'elevation_1984', 'creation_timestamp_ms': 1692073379523, 'update_timestamp_ms': 1692080951075, 'start_timestamp_ms': 1692080944463, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.13661807775497437, 'id': 'PQIASEC3WJTWRDSO25TT2IJS', 'name': 'projects/earthengine-legacy/operations/PQIASEC3WJTWRDSO25TT2IJS'}
# Waiting for task E3RY7VOW5SY4C4D2CR447IZE to complete...
# Task E3RY7VOW5SY4C4D2CR447IZE completed with status {'state': 'COMPLETED', 'description': 'elevation_1985', 'creation_timestamp_ms': 1692073380940, 'update_timestamp_ms': 1692080952584, 'start_timestamp_ms': 1692080944468, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.21497000753879547, 'id': 'E3RY7VOW5SY4C4D2CR447IZE', 'name': 'projects/earthengine-legacy/operations/E3RY7VOW5SY4C4D2CR447IZE'}
# Waiting for task IW3LXLMYHZQNH2YNC3RKUEHN to complete...
# Task IW3LXLMYHZQNH2YNC3RKUEHN completed with status {'state': 'COMPLETED', 'description': 'elevation_1986', 'creation_timestamp_ms': 1692073382102, 'update_timestamp_ms': 1692080961402, 'start_timestamp_ms': 1692080954604, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1371152549982071, 'id': 'IW3LXLMYHZQNH2YNC3RKUEHN', 'name': 'projects/earthengine-legacy/operations/IW3LXLMYHZQNH2YNC3RKUEHN'}
# Waiting for task UVGAESYATM37APEDVVR7UN6I to complete...
# Task UVGAESYATM37APEDVVR7UN6I completed with status {'state': 'COMPLETED', 'description': 'elevation_1987', 'creation_timestamp_ms': 1692073383541, 'update_timestamp_ms': 1692080961664, 'start_timestamp_ms': 1692080954604, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.18105918169021606, 'id': 'UVGAESYATM37APEDVVR7UN6I', 'name': 'projects/earthengine-legacy/operations/UVGAESYATM37APEDVVR7UN6I'}
# Waiting for task YBONZ342DL6PPMFY7XFR4EGS to complete...
# Task YBONZ342DL6PPMFY7XFR4EGS completed with status {'state': 'COMPLETED', 'description': 'elevation_1988', 'creation_timestamp_ms': 1692073384511, 'update_timestamp_ms': 1692080979408, 'start_timestamp_ms': 1692080964532, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1930921971797943, 'id': 'YBONZ342DL6PPMFY7XFR4EGS', 'name': 'projects/earthengine-legacy/operations/YBONZ342DL6PPMFY7XFR4EGS'}
# Waiting for task OIXWNK26XRXB65WWD5KM3QRY to complete...
# Task OIXWNK26XRXB65WWD5KM3QRY completed with status {'state': 'COMPLETED', 'description': 'elevation_1989', 'creation_timestamp_ms': 1692073385678, 'update_timestamp_ms': 1692080972820, 'start_timestamp_ms': 1692080964530, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.16147498786449432, 'id': 'OIXWNK26XRXB65WWD5KM3QRY', 'name': 'projects/earthengine-legacy/operations/OIXWNK26XRXB65WWD5KM3QRY'}
# Waiting for task LYA6FG5SQA72PFMJ7AS3SCRU to complete...
# Task LYA6FG5SQA72PFMJ7AS3SCRU completed with status {'state': 'COMPLETED', 'description': 'elevation_1990', 'creation_timestamp_ms': 1692073386852, 'update_timestamp_ms': 1692080984576, 'start_timestamp_ms': 1692080974612, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.23791873455047607, 'id': 'LYA6FG5SQA72PFMJ7AS3SCRU', 'name': 'projects/earthengine-legacy/operations/LYA6FG5SQA72PFMJ7AS3SCRU'}
# Waiting for task X56NMGUXZPJ4IHEE45TPRPI7 to complete...
# Task X56NMGUXZPJ4IHEE45TPRPI7 completed with status {'state': 'COMPLETED', 'description': 'elevation_1991', 'creation_timestamp_ms': 1692073388065, 'update_timestamp_ms': 1692080983797, 'start_timestamp_ms': 1692080974610, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.4817410707473755, 'id': 'X56NMGUXZPJ4IHEE45TPRPI7', 'name': 'projects/earthengine-legacy/operations/X56NMGUXZPJ4IHEE45TPRPI7'}
# Waiting for task 7P4I4RHLQYDSBZLF6DGZDC3U to complete...
# Task 7P4I4RHLQYDSBZLF6DGZDC3U completed with status {'state': 'COMPLETED', 'description': 'elevation_1992', 'creation_timestamp_ms': 1692073389365, 'update_timestamp_ms': 1692080991613, 'start_timestamp_ms': 1692080984900, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.13785448670387268, 'id': '7P4I4RHLQYDSBZLF6DGZDC3U', 'name': 'projects/earthengine-legacy/operations/7P4I4RHLQYDSBZLF6DGZDC3U'}
# Waiting for task SHQJ7NXAZUVN4OWZUTTU3I65 to complete...
# Task SHQJ7NXAZUVN4OWZUTTU3I65 completed with status {'state': 'COMPLETED', 'description': 'elevation_1993', 'creation_timestamp_ms': 1692073390762, 'update_timestamp_ms': 1692081002699, 'start_timestamp_ms': 1692080984897, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.20341618359088898, 'id': 'SHQJ7NXAZUVN4OWZUTTU3I65', 'name': 'projects/earthengine-legacy/operations/SHQJ7NXAZUVN4OWZUTTU3I65'}
# Waiting for task I3O3OBWAM2TF3LZ7Q3QBTV3D to complete...
# Task I3O3OBWAM2TF3LZ7Q3QBTV3D completed with status {'state': 'COMPLETED', 'description': 'elevation_1994', 'creation_timestamp_ms': 1692073391794, 'update_timestamp_ms': 1692081009759, 'start_timestamp_ms': 1692080994545, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.15757960081100464, 'id': 'I3O3OBWAM2TF3LZ7Q3QBTV3D', 'name': 'projects/earthengine-legacy/operations/I3O3OBWAM2TF3LZ7Q3QBTV3D'}
# Waiting for task 6MGN4H235LKDYPGXGHNUAIXR to complete...
# Task 6MGN4H235LKDYPGXGHNUAIXR completed with status {'state': 'COMPLETED', 'description': 'elevation_1995', 'creation_timestamp_ms': 1692073392989, 'update_timestamp_ms': 1692081001411, 'start_timestamp_ms': 1692080994538, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.12165872752666473, 'id': '6MGN4H235LKDYPGXGHNUAIXR', 'name': 'projects/earthengine-legacy/operations/6MGN4H235LKDYPGXGHNUAIXR'}
# Waiting for task UQ2L4CVTTMKTHFGSMV7Y6SZN to complete...
# Task UQ2L4CVTTMKTHFGSMV7Y6SZN completed with status {'state': 'COMPLETED', 'description': 'elevation_1996', 'creation_timestamp_ms': 1692073394168, 'update_timestamp_ms': 1692081013047, 'start_timestamp_ms': 1692081004840, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.18162141740322113, 'id': 'UQ2L4CVTTMKTHFGSMV7Y6SZN', 'name': 'projects/earthengine-legacy/operations/UQ2L4CVTTMKTHFGSMV7Y6SZN'}
# Waiting for task INRE6TD4NLIY4HGPATAU7ZMA to complete...
# Task INRE6TD4NLIY4HGPATAU7ZMA completed with status {'state': 'COMPLETED', 'description': 'elevation_1997', 'creation_timestamp_ms': 1692073395421, 'update_timestamp_ms': 1692081021727, 'start_timestamp_ms': 1692081014663, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.14129582047462463, 'id': 'INRE6TD4NLIY4HGPATAU7ZMA', 'name': 'projects/earthengine-legacy/operations/INRE6TD4NLIY4HGPATAU7ZMA'}
# Waiting for task K2FRJUADQDMUQBMQ3ERVZORX to complete...
# Task K2FRJUADQDMUQBMQ3ERVZORX completed with status {'state': 'COMPLETED', 'description': 'elevation_1998', 'creation_timestamp_ms': 1692073396675, 'update_timestamp_ms': 1692081021349, 'start_timestamp_ms': 1692081014682, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.1420421600341797, 'id': 'K2FRJUADQDMUQBMQ3ERVZORX', 'name': 'projects/earthengine-legacy/operations/K2FRJUADQDMUQBMQ3ERVZORX'}
# Waiting for task M2O4FDHUUW4EJRQIQHHDC2AS to complete...
# Task M2O4FDHUUW4EJRQIQHHDC2AS completed with status {'state': 'COMPLETED', 'description': 'elevation_1999', 'creation_timestamp_ms': 1692073398208, 'update_timestamp_ms': 1692081028631, 'start_timestamp_ms': 1692081014679, 'task_type': 'EXPORT_IMAGE', 'destination_uris': ['https://drive.google.com/#folders/19gg-R1btK6xpWSYOwUrC6DG8MkfC-Nxh'], 'attempt': 1, 'batch_eecu_usage_seconds': 0.18982122838497162, 'id': 'M2O4FDHUUW4EJRQIQHHDC2AS', 'name': 'projects/earthengine-legacy/operations/M2O4FDHUUW4EJRQIQHHDC2AS'}
# all tasks completed!
